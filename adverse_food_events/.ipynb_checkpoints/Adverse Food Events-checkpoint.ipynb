# %% [markdown]
# # Adverse  Events
#
# This analyisis has the purpose of investigating on the adverse events related to edible and non-edible products, occured in the United States over time.
# The analysis will consider adverse events reports in different areas and for different categories, and the effects that the related medical conditions had on the subject.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap
import seaborn as sns

# %%
df = pd.read_csv('event_stat.csv')

# %%
df.columns
# Out:
# Index(['RA_Report #', 'RA_CAERS Created Date', 'AEC_Event Start Date',
#        'PRI_Product Role', 'PRI_Reported Brand/Product Name',
#        'PRI_FDA Industry Code', 'PRI_FDA Industry Name',
#        'CI_Age at Adverse Event', 'CI_Age Unit', 'CI_Gender',
#        'AEC_One Row Outcomes', 'SYM_One Row Coded Symptoms'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0        65325              1/1/2004             8/4/2003          Suspect
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
# 5        65345              1/1/2004           12/21/2003          Suspect
# 6        65350              1/1/2004                  NaN          Suspect
# 7        65353              1/2/2004            12/1/2003          Suspect
# 8        65353              1/2/2004            12/1/2003          Suspect
# 9        65354              1/2/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
# 5        FRITO LAY FUNYUNS ONION FLAVOR, ONION RINGS                      7
# 6                                              GRAPE                     20
# 7                                HERBALIFE RELAX NOW                     54
# 8                            HERBALIFE TOTAL CONTROL                     54
# 9                                            YOHIMBE                     54
#
#                     PRI_FDA Industry Name  CI_Age at Adverse Event  \
# 0             Bakery Prod/Dough/Mix/Icing                      2.0
# 1             Bakery Prod/Dough/Mix/Icing                      2.0
# 2                          Ice Cream Prod                      NaN
# 3                          Baby Food Prod                      3.0
# 4                          Baby Food Prod                      NaN
# 5                         Snack Food Item                     10.0
# 6                        Fruit/Fruit Prod                      NaN
# 7  Vit/Min/Prot/Unconv Diet(Human/Animal)                      NaN
# 8  Vit/Min/Prot/Unconv Diet(Human/Animal)                      NaN
# 9  Vit/Min/Prot/Unconv Diet(Human/Animal)                     66.0
#
#      CI_Age Unit      CI_Gender  \
# 0        Year(s)         Female
# 1        Year(s)         Female
# 2  Not Available         Female
# 3       Month(s)  Not Available
# 4  Not Available  Not Available
# 5        Year(s)           Male
# 6  Not Available  Not Available
# 7  Not Available         Female
# 8  Not Available         Female
# 9        Year(s)           Male
#
#                                 AEC_One Row Outcomes  \
# 0  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 1  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 2                                      VISITED AN ER
# 3                      NON-SERIOUS INJURIES/ ILLNESS
# 4                     VISITED A HEALTH CARE PROVIDER
# 5                      NON-SERIOUS INJURIES/ ILLNESS
# 6                                              DEATH
# 7                     VISITED A HEALTH CARE PROVIDER
# 8                     VISITED A HEALTH CARE PROVIDER
# 9          REQ. INTERVENTION TO PRVNT PERM. IMPRMNT.
#
#                           SYM_One Row Coded Symptoms
# 0  SWELLING FACE, RASH, WHEEZING, COUGH, HOSPITAL...
# 1  SWELLING FACE, WHEEZING, COUGH, RASH, HOSPITAL...
# 2                       NAUSEA, DYSGEUSIA, DIARRHOEA
# 3                GASTROINTESTINAL DISORDER, VOMITING
# 4    GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION
# 5                                            CHOKING
# 6                                     DEATH, CHOKING
# 7           PARANOIA, PHYSICAL EXAMINATION, DELUSION
# 8           PARANOIA, PHYSICAL EXAMINATION, DELUSION
# 9                           BLOOD PRESSURE INCREASED

# %% [markdown]
# ## Data clean-up

# %%
len(df)
# Out:
# 90786

# %%
df.duplicated('RA_Report #').value_counts()
# Out:
# False    64517
# True     26269
# dtype: int64

# %%
df.drop_duplicates(['RA_Report #'],keep='last',inplace=True)

# %%
len(df)
# Out:
# 64517

# %%
df.head(5)
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
# 5        65345              1/1/2004           12/21/2003          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
# 5        FRITO LAY FUNYUNS ONION FLAVOR, ONION RINGS                      7
#
#          PRI_FDA Industry Name  CI_Age at Adverse Event    CI_Age Unit  \
# 1  Bakery Prod/Dough/Mix/Icing                      2.0        Year(s)
# 2               Ice Cream Prod                      NaN  Not Available
# 3               Baby Food Prod                      3.0       Month(s)
# 4               Baby Food Prod                      NaN  Not Available
# 5              Snack Food Item                     10.0        Year(s)
#
#        CI_Gender                               AEC_One Row Outcomes  \
# 1         Female  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 2         Female                                      VISITED AN ER
# 3  Not Available                      NON-SERIOUS INJURIES/ ILLNESS
# 4  Not Available                     VISITED A HEALTH CARE PROVIDER
# 5           Male                      NON-SERIOUS INJURIES/ ILLNESS
#
#                           SYM_One Row Coded Symptoms
# 1  SWELLING FACE, WHEEZING, COUGH, RASH, HOSPITAL...
# 2                       NAUSEA, DYSGEUSIA, DIARRHOEA
# 3                GASTROINTESTINAL DISORDER, VOMITING
# 4    GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION
# 5                                            CHOKING

# %% [markdown]
# ## Question 1: What are the most commonly reported foodstuffs?

# %%
foodstuff = df['PRI_FDA Industry Name'].value_counts()
food_index = foodstuff.index
food_value = foodstuff.values
plt.figure(figsize=(20,12))
plt.grid()
food_plot = sns.barplot(x=food_index[:30],y=food_value[:30], palette = "RdPu_r")
plt.xticks(rotation=60, ha='right', size=14)
plt.yticks(size=14)
plt.xlabel('Category', size=16, color='r')
plt.ylabel('Reported Events', size=16, color='r')
plt.show()

# %% [markdown]
# ## Question 2: What's the Product Role Distribution?

# %%
plt.figure(figsize=(12,8))

colors= ['lightcoral', 'lightblue']
explode= [0, 0.2]
df['PRI_Product Role'].value_counts().plot.bar(color=colors)
plt.xticks(size=14, rotation='horizontal')
plt.xlabel('Role', size=16, color='r')
plt.ylabel('Number of Cases', size=16, color='r')
plt.title('Product Role', size=22)
plt.show()

# %%
#suspect = df.loc[df['PRI_Product Role']=='Suspect']
#susper = suspect['PRI_Product Role'].count()
#contaminant = df.loc[df['PRI_Product Role']=='Contaminant']
#contaper = contaminant['PRI_Product Role'].count()

#print('Suspect percentage: {}%'.format(round(susper/len(df),3)*100))
#print('Contaminant percentage: {}%'.format(round(contaper/len(df),100)*100))

# %% [markdown]
# ## Question 3: What are the most commonly reported medical conditions?

# %%
symptoms = df['SYM_One Row Coded Symptoms'].value_counts()
symptom_index = symptoms.index
symptom_value = symptoms.values
plt.figure(figsize=(15,8))
plt.grid()
symptom_plot = sns.barplot(x=symptom_index[:20],y=symptom_value[:20], palette = "Blues")
plt.xticks(rotation=45, ha='right', size=14)
plt.yticks(size=14)
plt.xlabel('Medical condition', size=16, color='r')
plt.ylabel('Reported Events', size=16,color='r')
plt.title('Most Commonly Reported Medical Conditions', size=22)
plt.show()

# %% [markdown]
# ## Question 4: What are the most commonly reported outcomes?

# %%
# outcomes = df['AEC_One Row Outcomes'].value_counts()
# outcome_index = outcomes.index
# outcome_value = outcomes.values
# plt.figure(figsize=(40,20))
# symptom_plot = sns.barplot(x=outcome_value[:20],y=outcome_index[:20], palette = "Reds", orient='h')
# plt.xticks(rotation=45, ha='right', size=26)
# plt.yticks(size=38)
# plt.xlabel('Category', size=16)
# plt.ylabel('Reported Events', size=16)
# plt.show()

# %%
non_serious_count = 0
hc_count = 0
er_count = 0
hosp_count = 0
death_count = 0
serious_count = 0
dis_count = 0



for i in df['AEC_One Row Outcomes']:
    if 'NON-SERIOUS INJURIES/ ILLNESS'in i:
        non_serious_count += 1
    if 'VISITED A HEALTH CARE PROVIDER'in i:
        hc_count += 1
    if 'VISITED AN ER'in i:
        er_count += 1
    if 'HOSPITALIZATION'in i:
        hosp_count += 1
    if 'DEATH'in i:
        death_count += 1
    if 'SERIOUS INJURIES/ ILLNESS'in i:
        serious_count += 1
    if 'DISABILITY'in i:
        dis_count += 1

# %%
print('NON-SERIOUS INJURIES/ ILLNESS percentage: {}%'.format(round(non_serious_count/len(df),3)*100))
print('VISITED A HEALTH CARE PROVIDER percentage: {}%'.format(round(hc_count/len(df),3)*100))
print('VISITED AN ER percentage: {}%'.format(round(er_count/len(df),3)*100))
print('HOSPITALIZATION percentage: {}%'.format(round(hosp_count/len(df),1)*100))
print('DEATH percentage: {}%'.format(round(death_count/len(df),3)*100))
print('SERIOUS INJURIES/ ILLNESS percentage: {}%'.format(round(serious_count/len(df),1)*100))
print('DISABILITY percentage: {}%'.format(round(dis_count/len(df),3)*100))
# Out:
# NON-SERIOUS INJURIES/ ILLNESS percentage: 37.4%
# VISITED A HEALTH CARE PROVIDER percentage: 20.8%
# VISITED AN ER percentage: 12.4%
# HOSPITALIZATION percentage: 10.0%
# DEATH percentage: 2.7%
# SERIOUS INJURIES/ ILLNESS percentage: 40.0%
# DISABILITY percentage: 2.4%

# %%
data = {'VISITED AN ER':hosp_count, 'VISITED A HEALTH CARE PROVIDER':hc_count, 'HOSPITALIZATION':hosp_count,
     'NON-SERIOUS INJURIES/ ILLNESS':non_serious_count,
     'SERIOUS INJURIES/ ILLNESS':serious_count,
     'DEATH':death_count,
     'DISABILITY':dis_count}

outcomesDF = pd.Series(data=data)

# %%
plt.figure(figsize=(12,8))
outcomesDF.sort_values().plot(kind='barh', color='lightgreen')
plt.title('Most Commonly Reported Outcomes',fontsize=22)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()
print(outcomesDF.sort_values(ascending=False))
# Out:
# SERIOUS INJURIES/ ILLNESS         25974
# NON-SERIOUS INJURIES/ ILLNESS     24144
# VISITED A HEALTH CARE PROVIDER    13397
# HOSPITALIZATION                    9221
# VISITED AN ER                      9221
# DEATH                              1728
# DISABILITY                         1567
# dtype: int64

# %% [markdown]
# ## Adverse Events Over Time

# %%
df['year'] = pd.DatetimeIndex(df['AEC_Event Start Date']).year
df['month'] = pd.DatetimeIndex(df['RA_CAERS Created Date']).month

# %%
years_data = df['year'].value_counts()
years_index = years_data.index  
years_values = years_data.values
plt.figure(figsize=(15,8))
plt.xticks(rotation = 60, ha='right')
plt.title('Adverse Events Over Time', fontsize=22)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of reports", fontsize=14)
years_plot = sns.barplot(x=years_index,y=years_values, palette = "Oranges_r")

# %%
month_data = df['month'].value_counts()
month_index = month_data.index  
month_values = month_data.values
plt.figure(figsize=(15,8))
plt.xticks(rotation = 60, ha='right')
plt.title('Adverse Food Events by Month', fontsize=22)
plt.xlabel("Month", fontsize=14)
plt.ylabel("Number of reports", fontsize=14)
years_plot = sns.barplot(x=month_index,y=month_values, palette = "BuPu_r")

# %% [markdown]
# ## What is the gender distribution of the reports?

# %%
male = df.loc[df['CI_Gender']=='Male'].count()[0]
female = df.loc[df['CI_Gender']=='Female'].count()[0]

labels = ['Male', 'Female']
explode = [0 ,0.05]
colors = ['lightcoral', 'lightblue']
plt.figure(figsize=(12,8))
plt.pie([male, female], autopct='%1.1f%%', shadow=True, explode=explode, colors=colors, labels=labels)
plt.title('Gender Distribution', size=22, color='red')


plt.show()

# %% [markdown]
# ## What are the most reported brands/products?

# %%
brand_data = df['PRI_Reported Brand/Product Name'].value_counts()
brand_index = brand_data.index  
brand_values = brand_data.values
plt.figure(figsize=(12,8))
plt.xticks(rotation = 60, ha='right', size=16)
plt.yticks(size=16)
plt.title('Most Commonly Reported Brand/Product', fontsize=26)
plt.xlabel("Reports", fontsize=20)
plt.ylabel("Brands/ Products", fontsize=20)
brand_plot = sns.barplot(x=brand_values[1:11],y=brand_index[1:11], palette = "hot_r", orient='h')

# %% [markdown]
# ## What's the relation between Ovarian Cancer and industry?

# %%
cancer_df = df[(df["SYM_One Row Coded Symptoms"]=="OVARIAN CANCER")]

# %%
industry_data = cancer_df['PRI_FDA Industry Name'].value_counts().sort_values(ascending=False)
industry_index = industry_data.index  
industry_values = industry_data.values
plt.figure(figsize=(12,8))
plt.xticks(rotation = 60, ha='right', size=16)
plt.yticks(size=16)
plt.title('Relation between industry and Ovarian Cancer', fontsize=26)
plt.xlabel("Industry", fontsize=20)
plt.ylabel("Reports", fontsize=20)
brand_plot = sns.barplot(x=industry_index,y=industry_values, palette = "YlGnBu_r")

# %% [markdown]
# ## What is the relations between deaths and industry?

# %%
#df[df['SYM_One Row Coded Symptoms']=='OVARIAN CANCER']['PRI_Reported Brand/Product Name'].value_counts()[1:25].sort_values(ascending=True).plot(kind='barh')

# %%
# plt.figure(figsize=(12,8))
# df[df['AEC_One Row Outcomes']=='DEATH']['PRI_FDA Industry Name'].value_counts()[1:25].sort_values(ascending=True).plot(kind='barh')
# plt.show()

# %%
death_df = df[(df["AEC_One Row Outcomes"]=="DEATH")]
death_df['PRI_FDA Industry Name']
# Out:
# 6                              Fruit/Fruit Prod
# 16       Vit/Min/Prot/Unconv Diet(Human/Animal)
# 17       Vit/Min/Prot/Unconv Diet(Human/Animal)
# 630      Vit/Min/Prot/Unconv Diet(Human/Animal)
# 676                        Fishery/Seafood Prod
#                           ...
# 90009                                 Cosmetics
# 90025                                 Cosmetics
# 90327             Vegetables/Vegetable Products
# 90332             Vegetables/Vegetable Products
# 90681    Vit/Min/Prot/Unconv Diet(Human/Animal)
# Name: PRI_FDA Industry Name, Length: 969, dtype: object

# %%
ind_data = death_df['PRI_FDA Industry Name'].value_counts()
ind_index = ind_data.index  
ind_values = ind_data.values
plt.figure(figsize=(12,8))
plt.xticks(rotation = 60, ha='right', size=16)
plt.yticks(size=16)
plt.title('Relation between industry and deaths', fontsize=26)
plt.xlabel("Industry", fontsize=20)
plt.ylabel("Numbry of Deaths", fontsize=20)
industry_plot = sns.barplot(x=ind_index,y=ind_values, palette = "YlGnBu_r")

# %% [markdown]
# ## What is the relation between disbility and industry?

# %%
dis_df = df[(df["AEC_One Row Outcomes"]=="DISABILITY")]

# %%
dis_data = dis_df['PRI_FDA Industry Name'].value_counts()
dis_index = dis_data.index  
dis_values = dis_data.values
plt.figure(figsize=(12,8))
plt.xticks(rotation = 60, ha='right', size=16)
plt.yticks(size=13)
plt.title('Relation between industry and disability', fontsize=26)
plt.xlabel("Number of Cases", fontsize=20)
plt.ylabel("Industry", fontsize=20)
industry_plot = sns.barplot(x=dis_values[:15],y=dis_index[:15], palette = "PuRd_r", orient='h')

# %% [markdown]
# ## Death by gender

# %%
plt.figure(figsize=(12,8))
gender_death_plot = sns.countplot(death_df['PRI_FDA Industry Name'],hue=death_df['CI_Gender'], palette='RdYlBu_r')

plt.xticks(rotation = 60, ha='right', size=13)
plt.yticks(size=13)
plt.title('Death By Gender', fontsize=26)
plt.xlabel("Industry", fontsize=20)
plt.ylabel("Industry", fontsize=20)
plt.show()
